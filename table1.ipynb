# %%
# Basic library of python
import pandas as pd
import numpy as np
import requests
import time

# BeautifulSoup Library
from bs4 import BeautifulSoup

# library to join Url Urljoin
from urllib.parse import urljoin

# selenium Library
import re
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait     
from selenium.webdriver.common.by import By


my_headers = {'USER-AGENT':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'} # initializing header to avoid error 403 access denied

mychrome = r'"C:\Users\harsh\Downloads\chromedriver_win32\chromedriver.exe"' # Initializing chrome browser
driver = webdriver.Chrome(mychrome)

restaurant_links = []

driver.get('https://www.zomato.com/bangalore/restaurants') # passsing url on chrome
driver.maximize_window()
time.sleep(3)

# Get scroll height
curr_height = driver.execute_script("return document.body.scrollHeight") # initializing scroller and getting current scrool height

for i in range(0,20):    # scrolling for 20 times
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") # initiates scroller

    # Wait to load page
    time.sleep(5)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    curr_height = new_height # update new height
    #i+=1
    #print(i)
    
soup = BeautifulSoup(driver.page_source,'html.parser') # This will return the html script 
link_class = soup.findAll('div', attrs={'class':'jumbo-tracker'}) # here jumbotracker is the common class between all restaurants 
#print(link_class) 
cnt = 0
for link in link_class:
    urls = link.find('a') # since url are placed in href attributes of <a> class</a> hence we find a in every iteration of link_class  
    
    try: # here if we dont do exception handling the code will throw an exception the ver moment it reaches a url with no href
        if 'href' in urls.attrs:
            cnt+=1
            restaurant_links.append(urljoin('https://www.zomato.com/',urls.get('href'))) # urljoin joins them and gets appended to list
    except:
        pass
    
    
restaurant_tag = [] # to store ratings of the restaurant
cnt2 = 0
tag_class = soup.findAll('div', attrs={'class':'sc-1q7bklc-1 cILgox'})
for tag in range(9,len(tag_class)):
    cnt2+=1
    restaurant_tag.append(tag_class[tag].string) # Tag.string gives us the content present in the div tag
    
restaurant_name = [] # to store name of the rstaurant
b = 0
class_name = soup.findAll('h4')
for name in class_name:
    restaurant_name.append(name.string) # h4 tag consist of heading in this case is name of restaurants
    
#table1_dataframe = pd.DataFrame(columns = [restaurant_links,restaurant_tag])
#print(table1_dataframe)

cuisine_list = []
rpcn = 0
cuisine_class = soup.findAll('p', attrs={'class': 'sc-1hez2tp-0 sc-imDdex AYTKB'})
#soup.findAll('p', attrs={'class': re.compile('sc-1hez2tp-0 sc-imDdex')})
for cuisine in cuisine_class:
    rpcn+=1
    cuisine_list.append(''.join([cuisine.getText()])) # using join ass it has a para of text that is to be scrapped as a single text so that it can be mapped with respt restaurant 
    
    
price_for_one_list = []
rpc = 0
price_class = soup.findAll('p', attrs={'class': 'sc-1hez2tp-0 sc-imDdex djnfgb'}) # to find all p tag with given class and as its paragraph tag so it consist of pragraphs
#soup.findAll('p', attrs={'class': re.compile('sc-1hez2tp-0 sc-imDdex')})
for price in price_class:
    rpc+=1
    price_for_one_list.append(''.join([price.getText()])) # getting all the text in list using get_text
    
    
    #/html/body/div[1]/div/div[12]/div/div[3]/div/div/a[2]/div[2]/p[1]
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_55972\2510718491.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(mychrome)

# %%
print(cuisine_list)
print(price_for_one_list)
print(rpcn)
print(rpc)
# Out:
# ['North Indian, Chinese, Sichuan', 'Biryani, Andhra, North Indian, Seafood', 'Burger, Fast Food, Biryani, Desserts, Beverages', 'Pizza, Fast Food, Desserts, Beverages', 'Burger, Fast Food, Desserts, Beverages', 'Biryani, Andhra, North Indian, Chinese, Mughlai, South Indian, Desserts, Beverages', 'South Indian, Street Food, North Indian, Chinese, Fast Food, Beverages, Desserts', 'Mughlai, Arabian, North Indian, Chinese, Seafood', 'North Indian, Biryani, Arabian, Chinese, Kebab, Beverages, Juices, Sichuan', 'Kerala, North Indian, Chinese, Lebanese, Biryani, Ice Cream, Beverages', 'Fast Food, Rolls, Burger', 'Ice Cream, Beverages, Shake', 'North Indian, Kebab, Hyderabadi, Mughlai, Chinese, Rolls', 'Pizza, Pasta, Sandwich, Fast Food, Desserts, Beverages', 'Mithai, Street Food', 'Biryani, Kebab', 'Biryani, South Indian, Kebab', 'Pizza, Fast Food, Desserts, Beverages', 'Ice Cream, Desserts, Shake', 'Biryani, Mughlai, Kebab, Afghan, Street Food, Beverages, Desserts', 'Biryani, Kebab, Hyderabadi, Lucknowi', 'Kerala, Chinese, South Indian, Arabian, Juices, Beverages, Shake', 'Pizza, Italian, Pasta, Fast Food', 'Chinese, Asian, Thai, Seafood, Malaysian', 'Fast Food, Burger, Pizza', 'Biryani, South Indian, Desserts, Beverages, Andhra', 'South Indian, North Indian, Chinese, Sandwich, Street Food, Ice Cream, Shake, Beverages', 'Bakery, Ice Cream', 'Andhra, Biryani, South Indian, Desserts, Beverages, Hyderabadi', 'Continental, Healthy Food, Fast Food, Burger, Sandwich, Chinese, Pasta, Beverages', 'Pizza, Fast Food', 'South Indian, Street Food, Chinese, Fast Food, Ice Cream, Beverages', 'South Indian, Biryani, Chinese, Arabian, Beverages, Shake', 'Healthy Food, North Indian, Pizza, Burger, Pasta, Biryani, Chinese, Beverages', 'Wraps, Rolls, North Indian, Desserts, Beverages', 'Healthy Food, Sandwich, Wraps, Salad, Fast Food, Beverages', 'Biryani, North Indian, Chinese, Mughlai, Seafood, Beverages, Desserts', 'Biryani, North Indian, Kebab', 'South Indian, Chinese, Street Food, Beverages, North Indian, Shake', 'Biryani, North Indian, Mughlai, Chinese, Sichuan', 'Ice Cream', 'Mexican, Wraps, Fast Food', 'Wraps, North Indian, Fast Food, Biryani, Ice Cream, Desserts, Beverages', 'South Indian, North Indian, Mithai, Chinese, Biryani', 'Biryani, North Indian, South Indian, Chinese, Seafood, Beverages', 'Burger, Fast Food, Beverages', 'North Indian, Biryani, Mughlai, Chinese, Kebab', 'Bakery, Desserts, Beverages', 'Biryani, Kebab, North Indian', 'Biryani, Chettinad, Chinese, North Indian', 'North Indian, Beverages, Desserts', 'Biryani, South Indian', 'Biryani, Andhra, North Indian, Chinese, Seafood', 'Beverages, Shake, Juices, Ice Cream, Desserts, Burger, Fast Food, Sandwich', 'Ice Cream, Desserts, Shake', 'Momos, Fast Food, Tibetan', 'Biryani, Mughlai', 'Biryani, Kebab, Mughlai, North Indian, Desserts', 'Andhra, Hyderabadi, Biryani, North Indian, Chinese, Beverages', 'Ice Cream, Desserts', 'Biryani, Hyderabadi, North Indian, Kebab, Mughlai, Desserts', 'Biryani, North Indian, Chinese, Mughlai, Kebab, Seafood, Ice Cream, Beverages', 'Fast Food, Chinese, Street Food, Burger, Pizza, Beverages, Ice Cream', 'Mithai, Street Food, Beverages, Desserts', 'Fast Food, Street Food, Maharashtrian, Rolls, Ice Cream', 'North Indian, Chinese, South Indian, Street Food, Fast Food, Desserts, Shake, Beverages', 'Burger, Fast Food, American', 'North Indian, Street Food, Healthy Food, Chinese, Desserts', 'North Indian, Mughlai, Chinese, Kebab, Rolls, Seafood, Arabian, Biryani', 'North Indian, Chinese, Mughlai', 'Biryani, Mughlai, Hyderabadi', 'Bakery, Desserts', 'South Indian', 'Biryani, South Indian', 'North Indian, South Indian, Chinese, Sandwich, Street Food, Ice Cream, Juices, Beverages', 'Chinese, Momos, Sichuan', 'Beverages, Desserts, Ice Cream, Waffle, Bakery, Healthy Food', 'Fast Food, Sandwich, Street Food', 'Pizza, Burger, Fast Food', 'South Indian, Street Food, Ice Cream, Desserts, Beverages, Shake', 'North Indian, Chinese, Arabian, Mughlai, Fast Food, Bevera ...
# ['₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹250 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹100 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹50 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹150 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for one', '₹200 for o ...
# 732
# 732

# %%
final_restaurant_name = []
c=0
for i in range(9,len(restaurant_name)):
    c+=1
    final_restaurant_name.append(restaurant_name[i])
print(final_restaurant_name)
# Out:
# ['Royal Restaurant', 'Meghana Foods', 'KFC', 'Pizza Hut', 'Burger King', 'Nandhana Palace', 'A2B - Adyar Ananda Bhavan', 'Al-Bek', 'Imperio Restaurant', 'Thalassery Restaurant', 'Five Star Chicken', 'Polar Bear', 'Kabab Magic', 'Onesta', 'Kanti Sweets', "Mani's Dum Biryani", 'Chickpet Donne Biryani House', 'MOJO Pizza - 2X Toppings', 'Corner House Ice Creams', 'Sharief Bhai', 'Behrouz Biryani', 'Kannur Food Point', "La Pino'z Pizza", 'Beijing Bites', 'Chicking', 'RNR Biryani - Taste Of 1953', 'Sri Udupi Food Hub', 'CakeZone', 'Andhra Gunpowder', 'FreshMenu', 'Ovenstory Pizza', 'Paakashala', 'Kannur Food Kitchen', 'EatFit', 'Faasos - Wraps & Rolls', 'Subway', 'Hyderabad Biryaani House', 'Paradise Biryani', 'Sri Udupi Park', 'Grill Biryanis', 'NIC Ice Creams', 'Taco Bell', 'BOX8 - Desi Meals', 'Krishna Vaibhava', 'Dindigul Thalappakatti', 'EasyBites by Empire', 'Punjabi Nawabi', 'WarmOven Cake & Desserts', 'Madeena Hotel', 'Ambur Star Briyani Since 1890', "Kapoor's Cafe", 'Donne Biriyani House', 'Shanmukha', 'Lassi Shop', 'Natural Ice Cream', 'WOW! Momo', 'Hotel Aditya', 'Potful - Claypot Biryanis', 'Narmada Chain of Restaurants', "Kwalitywall's Frozen Dessert And Ice Cream Shop", 'Biryani By Kilo', 'Aromas Of Biryani', 'Big Bite', 'Anand Sweets And Savouries', 'Goli Vada Pav No. 1', 'Roti Ghar', "Wendy's", 'Roti-Wala.Com', 'M.M.A Kabab and Rolls', 'Sardarji Londonwaley', 'Biryani Trip - Destination Hyderabad', 'Bakingo', 'Madurai Idly Shop', 'Donne Biryani House', 'Savi Sagar', 'Chinese Wok', 'Frozen Bottle - Milkshakes, Desserts and Ice Cream', 'Hari Super Sandwich', 'Pizza@99', 'Priyadarshini Grand', 'Moriz Nano Restaurant', "Amma's Pastries", 'Nagarjuna', 'Vijayalakshmi Veg', 'Meat And Eat', 'Rolls On Wheels', 'Royal Biryani Kitchen', 'Chulha Chauki Da Dhaba', 'Savoury Restaurant', 'Chowman', 'Barbeque Nation', 'The Pizza Bakery', 'New Shanthi Sagar', 'Call Me Chow', 'The Belgian Waffle Co.', 'Big Bowl Company', 'Baskin Robbins', "Glen's Bakehouse", 'Paratha Envy', 'Pathaan Sir', 'Razakhiya Hotel', 'Great Indian Khichdi by EatFit', 'Shanthi Sagar', 'Theobroma', 'Rotti Walla', 'Kolkata Kathi Rolls', 'Meghduth Biryanis', 'Kaati Zone Rolls and Wraps', 'Namaste', 'Sultan - Palace Darbar Restaurant', 'Hotel Kadamba Veg', 'Anjappar', 'LunchBox - Meals and Thalis', 'Mandya Nati Style', 'T’s 21 Spice Biryani', 'Hyderabad Biryani House', 'Sagar Hotel', 'New Udupi Grand', 'New Udupi Garden', 'Siddique Kabab Centre', 'NH1 Bowls - Highway To North', 'Sai Prasadam', 'The Biryani Life', 'UBQ By Barbeque Nation', 'New Krishna Sagar', 'Beyond The Crust - BTC', 'Biryani Blues', 'Swad Punjab Da', 'Swathi', "Dande's Hyderabad Biryani", 'Szechuan Dragon', 'Andhra Biryanis', 'The Parotta Combo', 'Smoor', 'WOW! China', 'Chai Point', 'New Agarwal Bhavan', 'Biryani Square', 'New Shanthi Sagar', 'Halli Jonne Biriyani', 'Ande Ka Funda', 'Samosa Party', '7 Plates', 'Donne Biryani Mane', 'Karnataka Biryani Point', '99 Varieties Dosa & Pav Bhaji', 'Ghee And Turmeric', 'Nadan Pothichoru', 'The Dessert Heaven - Pure Veg', 'Chikpet Donne Biriyani House', '99 Variety Dosa & Pav Bhaji', 'Delicacy', 'Indraprastha Restaurant', "Kataria's", 'Five Star New Ambur Biryani', 'Zomoz - The Momo Company', 'Kabab King', 'Ambur Biryani Point', 'Mangalore Kitchen', 'Calicut Cafe Restaurant', 'Momoz', 'Ambur Hot Dum Biryani', 'Kirti Kitchen', 'Ayodhya Sagar', 'Kailash Parbat', 'Chinese BAE', "Mealful Rolls - India's Biggest Rolls", 'Biggies Burger', 'Charminar Biryani House', 'Punjabi Unplugged', 'Asha Sweet Center', 'Keventers - Milkshakes & Desserts', 'The Good Bowl', 'New Punjabi Hotel', 'King Punjabi Restaurant', 'Ayodhya Vihar Pure Veg', 'Rajanna Military Hotel', 'Pizza House', 'Sree Banashankari Donne Biriyani', 'Yumlane Pizza', 'Hotel N.G.T Non Veg', 'Kabab King Restaurant', 'Cream Stone Ice Cream', 'Chaat Street', 'Donne Biryani Palace', 'Jose Mess', "Adiga's", 'ZAZA 22 Spice Biryani', 'The Bake Feast', 'Laddoos', "Chetty's Corner", 'ITC Master Chef Creations', 'R ...

# %%
a = 0
restaurant_New_links = []
for i in range(21,len(restaurant_links)):
    a+=1
    restaurant_New_links.append(restaurant_links[i])

print(restaurant_New_links)
len(restaurant_New_links)
#table1_dataframe = pd.DataFrame(columns = [restaurant_links,restaurant_tag])
#print(table1_dataframe)
# Out:
# ['https://www.zomato.com/bangalore/royal-restaurant-shivajinagar/order', 'https://www.zomato.com/bangalore/meghana-foods-residency-road/order', 'https://www.zomato.com/bangalore/kfc-brigade-road-bangalore/order', 'https://www.zomato.com/bangalore/pizza-hut-shanti-nagar/order', 'https://www.zomato.com/bangalore/burger-king-commercial-street/order', 'https://www.zomato.com/bangalore/nandhana-palace-indiranagar/order', 'https://www.zomato.com/bangalore/a2b-adyar-ananda-bhavan-1-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/al-bek-malleshwaram/order', 'https://www.zomato.com/bangalore/imperio-restaurant-1-koramangala-7th-block-bangalore/order', 'https://www.zomato.com/bangalore/thalassery-restaurant-kammanahalli/order', 'https://www.zomato.com/bangalore/five-star-chicken-shivajinagar-bangalore/order', 'https://www.zomato.com/bangalore/polar-bear-1-basavanagudi/order', 'https://www.zomato.com/bangalore/kabab-magic-basavanagudi/order', 'https://www.zomato.com/bangalore/onesta-malleshwaram-bangalore/order', 'https://www.zomato.com/bangalore/kanti-sweets-brigade-road/order', 'https://www.zomato.com/bangalore/manis-dum-biryani-ulsoor/order', 'https://www.zomato.com/bangalore/chickpet-donne-biryani-house-jayanagar-bangalore/order', 'https://www.zomato.com/bangalore/mojo-pizza-2x-toppings-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/corner-house-ice-creams-residency-road-bangalore/order', 'https://www.zomato.com/bangalore/sharief-bhai-frazer-town-bangalore/order', 'https://www.zomato.com/bangalore/behrouz-biryani-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/kannur-food-point-btm/order', 'https://www.zomato.com/bangalore/la-pinoz-pizza-jayanagar-bangalore/order', 'https://www.zomato.com/bangalore/beijing-bites-richmond-road/order', 'https://www.zomato.com/bangalore/chicking-1-rajajinagar-bangalore/order', 'https://www.zomato.com/bangalore/rnr-biryani-taste-of-1953-1-jayanagar-bangalore/order', 'https://www.zomato.com/bangalore/sri-udupi-food-hub-majestic-bangalore/order', 'https://www.zomato.com/bangalore/cakezone-koramangala-6th-block-bangalore/order', 'https://www.zomato.com/bangalore/andhra-gunpowder-seshadripuram-bangalore/order', 'https://www.zomato.com/bangalore/freshmenu-richmond-road/order', 'https://www.zomato.com/bangalore/ovenstory-pizza-1-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/paakashala-mg-road-bangalore/order', 'https://www.zomato.com/bangalore/kannur-food-kitchen-btm-bangalore/order', 'https://www.zomato.com/bangalore/eatfit-cunningham-road-bangalore/order', 'https://www.zomato.com/bangalore/faasos-wraps-rolls-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/subway-lavelle-road/order', 'https://www.zomato.com/bangalore/hyderabad-biryaani-house-koramangala-5th-block/order', 'https://www.zomato.com/bangalore/paradise-biryani-rajajinagar-bangalore/order', 'https://www.zomato.com/bangalore/sri-udupi-park-residency-road/order', 'https://www.zomato.com/bangalore/grill-biryanis-1-malleshwaram-bangalore/order', 'https://www.zomato.com/bangalore/nic-ice-creams-frazer-town-bangalore/order', 'https://www.zomato.com/bangalore/taco-bell-brigade-road-bangalore/order', 'https://www.zomato.com/bangalore/box8-desi-meals-shanti-nagar-bangalore/order', 'https://www.zomato.com/bangalore/krishna-vaibhava-vijay-nagar-bangalore/order', 'https://www.zomato.com/bangalore/dindigul-thalappakatti-brigade-road-bangalore/order', 'https://www.zomato.com/bangalore/easybites-by-empire-brigade-road-bangalore/order', 'https://www.zomato.com/bangalore/punjabi-nawabi-koramangala-7th-block-bangalore/order', 'https://www.zomato.com/bangalore/warmoven-cake-desserts-vasanth-nagar-bangalore/order', 'https://www.zomato.com/bangalore/madeena-hotel-koramangala-5th-block-bangalore/order', 'https://www.zomato.com/bangalore/ambur-star-briyani-since-1890-indiranagar-bangalore/order', 'https://www.zomato.com/bangalore/kapoors-cafe-rajajinagar-bangalore/order', 'https://www. ...
# 732

# %%
print(len(restaurant_New_links))
print(len(final_restaurant_name))
print(len(restaurant_tag))
print(len(price_for_one_list)) 
print(len(cuisine_list))
maintable_dataframe = pd.DataFrame({'links':restaurant_New_links,'Name':final_restaurant_name, 'tags':restaurant_tag, 'price for One':price_for_one_list, 'cuisine':cuisine_list})
table1_dataframe # creating datafrome and converting to csv file
maintable_dataframe.to_csv('Maintable.csv')
# Out:
# 732
# 732
# 732
# 732
# 732
